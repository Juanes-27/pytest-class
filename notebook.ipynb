# %% [markdown]
# <a href="https://colab.research.google.com/github/Juanes-27/pytest-class/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
var = 2

# %%
assert var == 1
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_4055/3180899372.py in <cell line: 0>()
# ----> 1 assert var == 1
#
# AssertionError:
